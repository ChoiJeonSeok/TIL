# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rc
# %matplotlib inline
from matplotlib import font_manager

f_path = "C:/windows/Fonts/malgun.ttf"
font_manager.FontProperties(fname=f_path).get_name()
rc('font', family='Malgun Gothic')
# Out:
# C:\Users\art\anaconda3\envs\tensorflow\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\art\anaconda3\envs\tensorflow\lib\site-packages\numpy\.libs\libopenblas.NOIJJG62EMASZI6NYURL6JBKM4EVBGM7.gfortran-win_amd64.dll
# C:\Users\art\anaconda3\envs\tensorflow\lib\site-packages\numpy\.libs\libopenblas64__v0.3.21-gcc_10_3_0.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
df = pd.read_csv("경찰청_연도별 음주운전 재범자 단속 실적 현황_20221231.csv", encoding='cp949')

# %%
df
# Out:
#      년도      1회     2회     3회     4회    5회    6회    7회이상
# 0   2010  179086  79314  30103   9705  3118   903     478
# 1   2011  151488  67195  26172   8925  3017   929     487
# 2   2012  142803  63990  25607   9094  3179  1085     525
# 3   2013  154992  69863  28862  10391  3718  1285     725
# 4   2014  142258  64813  28183  10534  3775  1396     829
# 5   2015  135096  63018  27552  10810  4171  1556     897
# 6   2016  125736  57666  25856  10494  4131  1599    1117
# 7   2017  114585  51130  23396   9364  3896  1527    1289
# 8   2018   90168  40648  19025   7884  3189  1280     866
# 9   2019   73572  31487  14693   6416  2696  1102     806
# 10  2020   64229  28347  13836   6273  2735  1228     901
# 11  2021   64300  27355  13278   6150  2636  1186     977
# 12  2022   75245  29676  13830   6473  2838  1238     983

# %%
# 1회~7회 이상까지의 column 선택
cols = df.columns[1:8]
print(cols)
# '총합' column 추가하고 1회~7회 이상 데이터 합산하여 저장
df['총합'] = df[cols].sum(axis=1)

df
# Out:
# Index([' 1회 ', ' 2회 ', ' 3회 ', ' 4회 ', ' 5회 ', ' 6회 ', ' 7회이상 '], dtype='object')
#      년도      1회     2회     3회     4회    5회    6회    7회이상       총합
# 0   2010  179086  79314  30103   9705  3118   903     478  302707
# 1   2011  151488  67195  26172   8925  3017   929     487  258213
# 2   2012  142803  63990  25607   9094  3179  1085     525  246283
# 3   2013  154992  69863  28862  10391  3718  1285     725  269836
# 4   2014  142258  64813  28183  10534  3775  1396     829  251788
# 5   2015  135096  63018  27552  10810  4171  1556     897  243100
# 6   2016  125736  57666  25856  10494  4131  1599    1117  226599
# 7   2017  114585  51130  23396   9364  3896  1527    1289  205187
# 8   2018   90168  40648  19025   7884  3189  1280     866  163060
# 9   2019   73572  31487  14693   6416  2696  1102     806  130772
# 10  2020   64229  28347  13836   6273  2735  1228     901  117549
# 11  2021   64300  27355  13278   6150  2636  1186     977  115882
# ...

# %%
cols
# Out:
# Index([' 1회 ', ' 2회 ', ' 3회 ', ' 4회 ', ' 5회 ', ' 6회 ', ' 7회이상 '], dtype='object')

# %%
cols = [col.strip() for col in df.columns]
df.columns = cols
df.columns
# Out:
# Index(['년도', '1회', '2회', '3회', '4회', '5회', '6회', '7회이상', '총합'], dtype='object')

# %%
counts = df.drop('년도', axis=1)

fig, axs = plt.subplots(nrows=3, ncols=3, figsize=(15,10))
axs = axs.flatten()

# 각 재범 횟수에 대해 가장 높은 값과 가장 낮은 값을 구합니다.
max_vals = counts.max().values
min_vals = counts.min().values

# 파스텔 [적색, 녹색, 회색]을 RGB 값으로 지정합니다.
pastel_red = (255/255, 120/255, 120/255)
pastel_green = (130/255, 255/255, 130/255)
pastel_gray = (170/255, 170/255, 170/255)

for i, col in enumerate(counts.columns):
    # 각 재범 횟수에 대해 바 그래프를 그립니다.
    # 각 막대의 색을 파스텔 회색으로 합니다.
    bars = axs[i].bar(df['년도'], counts[col], color=pastel_gray)
    
    # 막대의 높이가 최댓값에 해당하는 경우 색을 파스텔 적색으로 변경합니다.
    # 막대의 높이가 최솟값에 해당하는 경우 색을 파스텔 녹색으로 변경합니다.
    for j, val in enumerate(counts[col].values):
        if val == max_vals[i]:
            bars[j].set_color(pastel_red)
        elif val == min_vals[i]:
            bars[j].set_color(pastel_green)
    
    axs[i].set_title(f'{col}')
    axs[i].set_xlabel('년도')
    axs[i].set_ylabel('재범자 수')

fig.suptitle('연도별 음주운전 재범자 수')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8,4))
plt.plot(df['년도'], df['1회'], label='1회')
plt.plot(df['년도'], df['2회'], label='2회')
plt.plot(df['년도'], df['3회'], label='3회')
plt.xlabel('년도')
plt.ylabel('음주운전 재범자 수')
plt.title('1회부터 3회까지 음주운전 재범자 수 추이')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8,4))
plt.plot(df['년도'], df['3회'], label='3회')
plt.plot(df['년도'], df['4회'], label='4회') 
plt.xlabel('년도')
plt.ylabel('음주운전 재범자 수')
plt.title('3회부터 4회까지 음주운전 재범자 수 추이')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8,4))
plt.plot(df['년도'], df['5회'], label='5회')
plt.plot(df['년도'], df['6회'], label='6회')
plt.plot(df['년도'], df['7회이상'], label='7회 이상')
plt.legend()
plt.xlabel('년도')
plt.ylabel('재범자 수')
plt.title('음주운전 재범자 수 추이 (5회 이상)')
plt.show()

# %%
# 추가 데이터 조사 및 데이터 불러오기
# 2021년까지 조사되어 있음.
driver = pd.read_csv('운전면허소지자현황__2010_2021.csv', encoding='cp949')
driver = driver.rename(columns={'시점': '년도', '총계':'운전면허 소지자 수'})
driver
# Out:
#       년도  운전면허 소지자 수
# 0   2010    26402364
# 1   2011    27251153
# 2   2012    28263317
# 3   2013    28848040
# 4   2014    29544245
# 5   2015    30293621
# 6   2016    31190359
# 7   2017    31665393
# 8   2018    32161081
# 9   2019    32649584
# 10  2020    33190565
# 11  2021    33729806

# %%
# 음주운전 단속 데이터 2021년으로 축소
new_df = df.iloc[:-1]
new_df.reset_index(drop=True)
print(new_df.info())
print(driver.info())
new_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   년도      12 non-null     int64
#  1   1회      12 non-null     int64
#  2   2회      12 non-null     int64
#  3   3회      12 non-null     int64
#  4   4회      12 non-null     int64
#  5   5회      12 non-null     int64
#  6   6회      12 non-null     int64
#  7   7회이상    12 non-null     int64
#  8   총합      12 non-null     int64
# dtypes: int64(9)
# memory usage: 992.0 bytes
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   년도          12 non-null     int64
#  1   운전면허 소지자 수  12 non-null     int64
# dtypes: int64(2)
# memory usage: 320.0 bytes
# None
#       년도      1회     2회     3회     4회    5회    6회  7회이상      총합
# ...

# %%
# 연도를 기준으로 두 데이터를 합침
drunk_driver = pd.concat([new_df.set_index('년도'), driver.set_index('년도')], axis=1, join='inner')
drunk_driver.reset_index(drop=True)


# 적발자 비율 계산 및 추가
drunk_driver["적발자비율"] = drunk_driver['총합'] / drunk_driver['운전면허 소지자 수']

# 적발자 비율이 포함된 데이터 확인 및 인덱스 정렬
drunk_driver = drunk_driver.reset_index()
drunk_driver
# Out:
#       년도      1회     2회     3회     4회    5회    6회  7회이상      총합  운전면허 소지자 수  \
# 0   2010  179086  79314  30103   9705  3118   903   478  302707    26402364
# 1   2011  151488  67195  26172   8925  3017   929   487  258213    27251153
# 2   2012  142803  63990  25607   9094  3179  1085   525  246283    28263317
# 3   2013  154992  69863  28862  10391  3718  1285   725  269836    28848040
# 4   2014  142258  64813  28183  10534  3775  1396   829  251788    29544245
# 5   2015  135096  63018  27552  10810  4171  1556   897  243100    30293621
# 6   2016  125736  57666  25856  10494  4131  1599  1117  226599    31190359
# 7   2017  114585  51130  23396   9364  3896  1527  1289  205187    31665393
# 8   2018   90168  40648  19025   7884  3189  1280   866  163060    32161081
# 9   2019   73572  31487  14693   6416  2696  1102   806  130772    32649584
# 10  2020   64229  28347  13836   6273  2735  1228   901  117549    33190565
# ...

# %%
# %pwd
# Out:
# 'C:\\WORKSPACE-PYTHON\\multicampus\\drunk\\data'

# %%
drunk_driver.to_csv('음주운전 적발 및 비율_2010_2021.csv', index=False, encoding='cp949')
